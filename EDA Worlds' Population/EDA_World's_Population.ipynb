# %%
#import necessary libaries
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
#reading file
df = pd.read_csv('world_population.csv')
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#set index by rank
df.set_index('Rank', inplace = True)

# %%
df.sort_index(inplace=True)
df.head(10)
#we sorted our countries from highest population to lowest
# Out:
#      CCA3 Country/Territory           Capital      Continent  2022 Population  \
# Rank
# 1     CHN             China           Beijing           Asia       1425887337
# 2     IND             India         New Delhi           Asia       1417173173
# 3     USA     United States  Washington, D.C.  North America        338289857
# 4     IDN         Indonesia           Jakarta           Asia        275501339
# 5     PAK          Pakistan         Islamabad           Asia        235824862
# 6     NGA           Nigeria             Abuja         Africa        218541212
# 7     BRA            Brazil          Brasilia  South America        215313498
# 8     BGD        Bangladesh             Dhaka           Asia        171186372
# 9     RUS            Russia            Moscow         Europe        144713314
# 10    MEX            Mexico       Mexico City  North America        127504125
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# ...

# %%
df.isnull().sum()
#no null values
# Out:
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      3.407441e+07     3.350107e+07     3.172996e+07     2.984524e+07
# std       1.367664e+08     1.355899e+08     1.304050e+08     1.242185e+08
# min       5.100000e+02     5.200000e+02     5.640000e+02     5.960000e+02
# 25%       4.197385e+05     4.152845e+05     4.046760e+05     3.931490e+05
# 50%       5.559944e+06     5.493074e+06     5.307400e+06     4.942770e+06
# 75%       2.247650e+07     2.144798e+07     1.973085e+07     1.915957e+07
# max       1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.626947e+07     2.271022e+07     1.898462e+07     1.578691e+07
# std       1.116982e+08     9.783217e+07     8.178519e+07     6.779509e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         234 non-null    object
#  1   Country/Territory            234 non-null    object
#  2   Capital                      234 non-null    object
#  3   Continent                    234 non-null    object
#  4   2022 Population              234 non-null    int64
#  5   2020 Population              234 non-null    int64
#  6   2015 Population              234 non-null    int64
#  7   2010 Population              234 non-null    int64
#  8   2000 Population              234 non-null    int64
#  9   1990 Population              234 non-null    int64
#  10  1980 Population              234 non-null    int64
#  11  1970 Population              234 non-null    int64
#  12  Area (km²)                   234 non-null    int64
# ...

# %%
df['Continent'].unique()
# Out:
# array(['Asia', 'North America', 'Africa', 'South America', 'Europe',
#        'Oceania'], dtype=object)

# %%
africa = df[df['Continent'] == 'Africa']
africa['Growth Rate'].sum() / df['Growth Rate'].sum()
#africa records 25 percent growth rate in worlds population
# Out:
# 0.2464046264600021

# %%
africa['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#africa holds 22 percent of world's area
# Out:
# 22.28292743488722

# %%
africa['World Population Percentage'].sum()
#africa holds 18 percent of world's population
# Out:
# 17.869999999999997

# %%
africa.head()
# Out:
#      CCA3 Country/Territory      Capital Continent  2022 Population  \
# Rank
# 6     NGA           Nigeria        Abuja    Africa        218541212
# 12    ETH          Ethiopia  Addis Ababa    Africa        123379924
# 14    EGY             Egypt        Cairo    Africa        110990103
# 15    COD          DR Congo     Kinshasa    Africa         99010212
# 22    TZA          Tanzania       Dodoma    Africa         65497748
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 6           208327405        183995785        160952853        122851984
# 12          117190911        102471895         89237791         67031867
# 14          107465134         97723799         87252413         71371371
# 15           92853164         78656904         66391257         48616317
# 22           61704518         52542823         45110527         34463704
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# Rank
# ...

# %%
africa.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     5.700000e+01     5.700000e+01     5.700000e+01     5.700000e+01
# mean      2.503037e+07     2.387144e+07     2.107197e+07     1.851277e+07
# std       3.757230e+07     3.582766e+07     3.162610e+07     2.770695e+07
# min       1.071180e+05     1.055300e+05     9.924000e+04     9.240900e+04
# 25%       2.567012e+06     2.489098e+06     2.253133e+06     2.022747e+06
# 50%       1.335286e+07     1.264312e+07     1.155778e+07     1.027073e+07
# 75%       2.961171e+07     2.822518e+07     2.485091e+07     2.173105e+07
# max       2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     5.700000e+01     5.700000e+01     5.700000e+01     5.700000e+01
# mean      1.436747e+07     1.119563e+07     8.448007e+06     6.411304e+06
# std       2.150001e+07     1.665599e+07     1.261294e+07     9.697234e+06
# ...

# %%
africa['1970 Population'].sum() / africa['2022 Population'].sum() * 100
#Africa records about 26 percent increase in its population since 1970
# Out:
# 25.6141042297105

# %%
africa['Country/Territory'].value_counts().sum()
#57 countires in africa
# Out:
# 57

# %%
africa['2022 Population'].sum() / africa['Area (km²)'].sum()
#density per km in africa
# Out:
# 47.05893110299

# %%
#lets work with asia now
asia = df[df['Continent'] == 'Asia']

# %%
asia.head()
# Out:
#      CCA3 Country/Territory    Capital Continent  2022 Population  \
# Rank
# 1     CHN             China    Beijing      Asia       1425887337
# 2     IND             India  New Delhi      Asia       1417173173
# 4     IDN         Indonesia    Jakarta      Asia        275501339
# 5     PAK          Pakistan  Islamabad      Asia        235824862
# 8     BGD        Bangladesh      Dhaka      Asia        171186372
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 1          1424929781       1393715448       1348191368       1264099069
# 2          1396387127       1322866505       1240613620       1059633675
# 4           271857970        259091970        244016173        214072421
# 5           227196741        210969298        194454498        154369924
# 8           167420951        157830000        148391139        129193327
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# Rank
# ...

# %%
asia.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     5.000000e+01     5.000000e+01     5.000000e+01     5.000000e+01
# mean      9.442767e+07     9.326173e+07     8.916500e+07     8.440083e+07
# std       2.797207e+08     2.775374e+08     2.672775e+08     2.548406e+08
# min       4.490020e+05     4.417250e+05     4.214370e+05     3.615750e+05
# 25%       5.309989e+06     5.180282e+06     4.775965e+06     4.243158e+06
# 50%       1.808292e+07     1.768805e+07     1.662672e+07     1.549568e+07
# 75%       4.998589e+07     4.952276e+07     4.768525e+07     4.442600e+07
# max       1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     5.000000e+01     5.000000e+01     5.000000e+01     5.000000e+01
# mean      7.470179e+07     6.421127e+07     5.270668e+07     4.289813e+07
# std       2.294235e+08     2.010543e+08     1.676305e+08     1.383442e+08
# ...

# %%
asia['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#asia holds 24 percent of wolrd's area
# Out:
# 23.620711714542754

# %%
asia['World Population Percentage'].sum()
#asia holds extraordinary 59 percent of world's population
# Out:
# 59.18999999999999

# %%
asia['1970 Population'].sum() / asia['2022 Population'].sum() * 100
#asia records about 45 percent increase in its population since 1970
# Out:
# 45.429615973176766

# %%
asia['Country/Territory'].value_counts().sum()
#50 countires in africa
# Out:
# 50

# %%
asia['2022 Population'].sum() / asia['Area (km²)'].sum()
#density per km in asia
# Out:
# 146.90903478206783

# %%
europe = df[df['Continent'] == 'Europe']
europe.head()
# Out:
#      CCA3 Country/Territory Capital Continent  2022 Population  \
# Rank
# 9     RUS            Russia  Moscow    Europe        144713314
# 19    DEU           Germany  Berlin    Europe         83369843
# 21    GBR    United Kingdom  London    Europe         67508936
# 23    FRA            France   Paris    Europe         64626628
# 25    ITA             Italy    Rome    Europe         59037474
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 9           145617329        144668389        143242599        146844839
# 19           83328988         82073226         81325090         81551677
# 21           67059474         65224364         62760039         58850043
# 23           64480053         63809769         62444567         58665453
# 25           59500579         60232906         59822450         56966397
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# Rank
# ...

# %%
europe.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     5.000000e+01     5.000000e+01     5.000000e+01     5.000000e+01
# mean      1.486295e+07     1.491584e+07     1.483071e+07     1.471228e+07
# std       2.726492e+07     2.739755e+07     2.717747e+07     2.686664e+07
# min       5.100000e+02     5.200000e+02     5.640000e+02     5.960000e+02
# 25%       6.322112e+05     6.293858e+05     5.855475e+05     5.380635e+05
# 50%       5.228714e+06     5.162979e+06     4.928058e+06     4.707163e+06
# 75%       1.046673e+07     1.047642e+07     1.048421e+07     1.055749e+07
# max       1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     5.000000e+01     5.000000e+01     5.000000e+01     5.000000e+01
# mean      1.452187e+07     1.440642e+07     1.385054e+07     1.311848e+07
# std       2.682928e+07     2.673980e+07     2.545821e+07     2.429469e+07
# ...

# %%
europe['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#Europe holds 17 percent of world's area
# Out:
# 16.912063602687645

# %%
europe['World Population Percentage'].sum()
#europe holds only 9 percent of world's population
# Out:
# 9.330000000000002

# %%
europe['1970 Population'].sum() / europe['2022 Population'].sum() * 100
#europe holds extraordinary 88 percent increase in population since 1970
# Out:
# 88.2629568773462

# %%
europe['Country/Territory'].value_counts().sum()
#50 countries in europe
# Out:
# 50

# %%
europe['2022 Population'].sum() / europe['Area (km²)'].sum()
#europe density is 32 per km
# Out:
# 32.296143602128616

# %%
northa = df[df['Continent'] == 'North America']
northa.head()
#now, lets work with north america
# Out:
#      CCA3 Country/Territory           Capital      Continent  2022 Population  \
# Rank
# 3     USA     United States  Washington, D.C.  North America        338289857
# 10    MEX            Mexico       Mexico City  North America        127504125
# 39    CAN            Canada            Ottawa  North America         38454327
# 68    GTM         Guatemala    Guatemala City  North America         17843908
# 82    HTI             Haiti    Port-au-Prince  North America         11584996
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 3           335942003        324607776        311182845        282398554
# 10          125998302        120149897        112532401         97873442
# 39           37888705         35732126         33963412         30683313
# 68           17362718         16001107         14543121         11735894
# 82           11306801         10563757          9842880          8360225
#
# ...

# %%
northa.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     4.000000e+01     4.000000e+01     4.000000e+01     4.000000e+01
# mean      1.500740e+07     1.485591e+07     1.425960e+07     1.356802e+07
# std       5.641806e+07     5.599277e+07     5.401366e+07     5.164505e+07
# min       4.390000e+03     4.500000e+03     5.059000e+03     4.938000e+03
# 25%       6.225450e+04     6.202975e+04     5.965700e+04     5.578175e+04
# 50%       2.363990e+05     2.349905e+05     2.268530e+05     2.228230e+05
# 75%       5.469720e+06     5.415512e+06     5.229198e+06     4.930622e+06
# max       3.382899e+08     3.359420e+08     3.246078e+08     3.111828e+08
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     4.000000e+01     4.000000e+01     4.000000e+01     4.000000e+01
# mean      1.215174e+07     1.053166e+07     9.207334e+06     7.885865e+06
# std       4.666350e+07     4.081068e+07     3.646815e+07     3.235526e+07
# ...

# %%
northa['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#north america holds 18 percent of world's area
# Out:
# 17.81885079457644

# %%
northa['World Population Percentage'].sum()
#north america holds only about 8 percent of world's population
# Out:
# 7.51

# %%
northa['1970 Population'].sum() / northa['2022 Population'].sum() * 100
#north america had 52 percent increase since 1970
# Out:
# 52.54649948304848

# %%
northa['Country/Territory'].value_counts().sum()
#north america have 40 countries
# Out:
# 40

# %%
northa['2022 Population'].sum() / northa['Area (km²)'].sum()
#north america density per km
# Out:
# 24.760424378999364

# %%
southa = df[df['Continent'] == 'South America']
southa.head()
#now, south america
# Out:
#      CCA3 Country/Territory       Capital      Continent  2022 Population  \
# Rank
# 7     BRA            Brazil      Brasilia  South America        215313498
# 28    COL          Colombia        Bogota  South America         51874024
# 33    ARG         Argentina  Buenos Aires  South America         45510318
# 44    PER              Peru          Lima  South America         34049588
# 51    VEN         Venezuela       Caracas  South America         28301696
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 7           213196304        205188205        196353492        175873720
# 28           50930662         47119728         44816108         39215135
# 33           45036032         43257065         41100123         37070774
# 44           33304756         30711863         29229572         26654439
# 51           28490453         30529716         28715022         24427729
#
# ...

# %%
southa.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     1.400000e+01     1.400000e+01     1.400000e+01     1.400000e+01
# mean      3.120119e+07     3.082357e+07     2.950960e+07     2.807702e+07
# std       5.572581e+07     5.517486e+07     5.308400e+07     5.080780e+07
# min       3.780000e+03     3.747000e+03     3.408000e+03     3.187000e+03
# 25%       1.462243e+06     1.455173e+06     1.416978e+06     1.399112e+06
# 50%       1.511256e+07     1.476238e+07     1.364299e+07     1.260643e+07
# 75%       3.261262e+07     3.210118e+07     3.066633e+07     2.910093e+07
# max       2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     1.400000e+01     1.400000e+01     1.400000e+01     1.400000e+01
# mean      2.497388e+07     2.122474e+07     1.727064e+07     1.378194e+07
# std       4.551073e+07     3.900401e+07     3.166669e+07     2.498639e+07
# ...

# %%
southa['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#south america holds 13 percent of world's area
# Out:
# 13.107079688190924

# %%
southa['World Population Percentage'].sum()
#south america holds 5 percent of world's population
# Out:
# 5.4799999999999995

# %%
southa['1970 Population'].sum() / southa['2022 Population'].sum() * 100
#south america had 44 percent increase in population since 1970
# Out:
# 44.171204223077524

# %%
southa['Country/Territory'].value_counts().sum()
#14 countries in south america
# Out:
# 14

# %%
southa['2022 Population'].sum() / southa['Area (km²)'].sum()
# south america density per km
# Out:
# 24.494322389325816

# %%
oceania = df[df['Continent'] == 'Oceania']
#now, oceania

# %%
oceania.head()
# Out:
#      CCA3 Country/Territory       Capital Continent  2022 Population  \
# Rank
# 55    AUS         Australia      Canberra   Oceania         26177413
# 93    PNG  Papua New Guinea  Port Moresby   Oceania         10142619
# 123   NZL       New Zealand    Wellington   Oceania          5185288
# 162   FJI              Fiji          Suva   Oceania           929766
# 166   SLB   Solomon Islands       Honiara   Oceania           724273
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 55           25670051         23820236         22019168         19017963
# 93            9749640          8682174          7583269          5508297
# 123           5061133          4590590          4346338          3855266
# 162            920422           917200           905169           832509
# 166            691191           612660           540394           429978
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# Rank
# ...

# %%
oceania.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count     2.300000e+01     2.300000e+01     2.300000e+01     2.300000e+01
# mean      1.958198e+06     1.910149e+06     1.756664e+06     1.613164e+06
# std       5.754935e+06     5.630356e+06     5.198146e+06     4.780727e+06
# min       1.871000e+03     1.827000e+03     1.454000e+03     1.367000e+03
# 25%       1.753300e+04     1.750050e+04     1.774450e+04     1.787600e+04
# 50%       1.141640e+05     1.121060e+05     1.094620e+05     1.075880e+05
# 75%       3.165095e+05     3.068025e+05     2.874095e+05     2.726070e+05
# max       2.617741e+07     2.567005e+07     2.382024e+07     2.201917e+07
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count     2.300000e+01     2.300000e+01     2.300000e+01     2.300000e+01
# mean      1.357512e+06     1.162775e+06     9.965322e+05     8.469683e+05
# std       4.076725e+06     3.611287e+06     3.115750e+06     2.668785e+06
# ...

# %%
oceania['Area (km²)'].sum() / df['Area (km²)'].sum() *100
#oceania holds 6 percent of worlds' area
# Out:
# 6.258366765115022

# %%
oceania['World Population Percentage'].sum()
#oceania holds only .5 percent of world's population
# Out:
# 0.55

# %%
oceania['1970 Population'].sum() / oceania['2022 Population'].sum() * 100
#oceania had 43 percent increase in population since 1970
# Out:
# 43.25243212737247

# %%
oceania['Country/Territory'].value_counts().sum()
#only 23 countries in oceania
# Out:
# 23

# %%
oceania['2022 Population'].sum() / oceania['Area (km²)'].sum()
#oceania density per km
# Out:
# 5.2892690040176955

# %%
#lets create a data frame for continents
data = df.drop(columns = ['CCA3', 'Capital','Country/Territory','Density (per km²)'])
continent = data.groupby('Continent').sum()

# %%
continent['Density (per km²)'] = continent['2022 Population'] / continent['Area (km²)']
continent
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa              1426730932       1360671810       1201102442
# Asia                4721383274       4663086535       4458250182
# Europe               743147538        745792196        741535608
# North America        600296136        594236593        570383850
# Oceania               45038554         43933426         40403283
# South America        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# South America        393078250        349634282        297146415
#
# ...

# %%
continent.head(6)
continent['Continents'] = continent.index


continent
#now lets work with visualization!
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa              1426730932       1360671810       1201102442
# Asia                4721383274       4663086535       4458250182
# Europe               743147538        745792196        741535608
# North America        600296136        594236593        570383850
# Oceania               45038554         43933426         40403283
# South America        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# South America        393078250        349634282        297146415
#
# ...

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x="Continents", y="2022 Population", data=continent)
#Asia has more population than all the continents combined
# Out:
# <Axes: xlabel='Continents', ylabel='2022 Population'>

# %%
rate = continent[['1970 Population','2022 Population','Continents']]




sns.lineplot(data=rate)
#we can see the rate of change from 1970 till 202
# Out:
# <Axes: xlabel='Continent'>

# %%
sns.barplot(
    x='Continents',
    y='Density (per km²)',
    data=continent
)
#despite being the most populated continent, asia has much more density than any other country
# Out:
# <Axes: xlabel='Continents', ylabel='Density (per km²)'>
